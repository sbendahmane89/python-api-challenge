# %%
# pip install citipy

# %%
#import the citipy module 
from citipy import citipy

# %%
# use citipy. nearest_city(lat, lng).city_name to find the nearest city name based on lat and lng coords

# + latitude = north henisphere / - latitude = southern hemisphere
# + longtitude = east of prime meridian / - Longitude = west of prime meridian 

cityName = citipy.nearest_city(33.748, -84.387).city_name

print(cityName)
# Out:
# atlanta

# %%
# generate a list of lats and lons and then add those to a tuple
# import numpy 
import numpy as np

# %%
# set the range of lats and longs for United States
latRange = (24, 50)
lngRange = (-125, -66.9)

# %%
# use np.random.uniform to generate a series of values in a range 
lats = np.random.uniform(latRange[0], latRange[1], size=50)
lons = np.random.uniform(lngRange[0], lngRange[1], size=50)

# zip the lists of lats and lons into tuple
latLongs = zip(lats, lons)

# %%
# Use nearest city to identify a city near each set of coordinates
cityNames = []

for coords in latLongs:
        # try to get a city name
        cityName = citipy.nearest_city(coords[0], coords[1]).city_name

        # check to see if the city is unique, if so, add to the list
        if cityName not in cityNames:
            cityNames.append(cityName)
            
for c in cityNames:
    print(c)
# Out:
# cooper's town
# pratt
# morehead city
# nueva rosita
# rosales
# charlestown
# penticton
# nantucket
# ramona
# heroica guaymas
# kill devil hills
# hard bargain
# high rock
# saltillo
# chadron
# cockburn town
# puerto penasco
# south lake tahoe
# carolina beach
# waupaca
# lompoc
# minot air force base
# roswell
# la haute-saint-charles
# rock springs
# blythe
# tucumcari
# chestertown
# rusk
# santiago papasquiaro
# grantsville
# amos
# nevada
# lazaro cardenas
# san diego country estates
# hamilton
# pecan plantation
# ciudad rio bravo
# north platte
# avenal
# helena valley southeast
# ellsworth
# puerto san carlos
# watertown
# franklin
# natchitoches
# winterville

# %%
import requests
import json
import pandas as pd

# %%
# open wather api key
api_key = "0bd2278df557b03681abe3f4ff47b83a"

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = 'imperial'
# build the base query url 
queryURL = f"{url}appid={api_key}&units={units}&q="

# %%
city = "Charlotte"
queryURL += city

weather = requests.get(queryURL)

weatherJSON = weather.json() # same as requests.get(queryURL).json()
weatherJSON # ['coord']['lat'] - ['coord'['lon'] - ['main'['temp']
# Out:
# {'coord': {'lon': -80.8431, 'lat': 35.2271},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01d'}],
#  'base': 'stations',
#  'main': {'temp': 54.59,
#   'feels_like': 51.12,
#   'temp_min': 51.57,
#   'temp_max': 55.98,
#   'pressure': 1023,
#   'humidity': 29,
#   'sea_level': 1023,
#   'grnd_level': 997},
#  'visibility': 10000,
#  'wind': {'speed': 3.31, 'deg': 206, 'gust': 5.59},
#  'clouds': {'all': 0},
#  'dt': 1741043990,
#  'sys': {'type': 2,
#   'id': 2007844,
#   'country': 'US',
#   'sunrise': 1741002615,
#   'sunset': 1741044035},
#  'timezone': -18000,
#  'id': 4460243,
#  'name': 'Charlotte',
#  'cod': 200}

# %%
import time

count = 0

while count < 5:
    time.sleep(1) # posses the program for 1 second
    count += 1
    if count == 1:
        print(f"Printed after {count} second")
    else:
         print(f"Printed after {count} seconds")
# Out:
# Printed after 1 second
# Printed after 2 seconds
# Printed after 3 seconds
# Printed after 4 seconds
# Printed after 5 seconds

# %%
# build a dataframe of city names and current temperatures, latitudes, and longitudes
temperatures = []
lats = []
lons = []
cities = []

queryURL = f"{url}appid={api_key}&units={units}&q="

for city in cityNames:

    try:
        time.sleep(1) # pauses the program for 1 second
        # create the new query string
        cityQuery= f"{queryURL}{city}"

        # call to requests and jsonify the response 
        response = requests.get(cityQuery).json()
        
        if response['coord']['lat'] > 50 or response['coord']['lat'] < 24: 
            pass
        elif response['coord']['lon'] < -125 or response['coord']['lon'] > -66.9:
            pass
        elif response['sys']['country'] != 'US':
            pass
        else:
            # extract the temperature and add to the tempratures list 
            temperatures.append(response['main']['temp'])

            # extract the latitude and add to the latitudes list 
            lats.append(response['coord']['lat'])

             # extract the longitude and dd to the longitudes list 
            lons.append(response['coord']['lon'])

            # extract the city name fram Open weather
            cities.append(response['name'])

    except:
        # just in case the temperature was not reported 
        pass 
        
# build the dataframe
cityDataDF = pd.DataFrame(
    {
        "City Name": cities,
        "Fahrenheit Temperature": temperatures,
        "Latitude": lats,
        "Longitude": lons
    }
)

cityDataDF
# Out:
#                     City Name  Fahrenheit Temperature  Latitude  Longitude
# 0                       Pratt                   59.22   37.6439   -98.7376
# 1               Morehead City                   47.52   34.7229   -76.7260
# 2                   Nantucket                   23.11   41.2835   -70.0995
# 3                      Ramona                   54.86   33.0417  -116.8681
# 4            Kill Devil Hills                   41.99   36.0307   -75.6760
# 5                     Chadron                   49.68   42.8294  -102.9999
# 6            South Lake Tahoe                   41.86   38.9332  -119.9844
# 7              Carolina Beach                   49.05   34.0352   -77.8936
# 8                     Waupaca                   40.12   44.3580   -89.0860
# 9                      Lompoc                   57.52   34.6391  -120.4579
# 10       Minot Air Force Base                   37.49   48.4209  -101.3391
# 11                    Roswell                   58.57   34.0232   -84.3616
# 12               Rock Springs                   39.72   41.5875  -109.2029
# 13                     Blythe                   70.25   33.6103  -114.5964
# 14                  Tucumcari                   66.04   35.1717  -103.7250
# 15                Chestertown                   36.25   39.2090   -76.0666
# 16                       Rusk                   66.72   31.7960   -95.1502
# 17                Grantsville                   47.26   40.5999  -112.4644
# 18                     Nevada                   28.80   39.2502  -116.7512
# 19  San Diego Country Estates                   54.25   33.0067  -116.7836
# 20                   Hamilton                   45.86   39.1834   -84.5333
# 21           Pecan Plantation                   75.24   32.3604   -97.6756
# 22               North Platte                   44.49   41.1239  -100.7654
# 23                     Avenal                   60.37   36.0041  -120.1290
# 24    Helena Valley Southeast                   36.19   46.6153  -111.9216
# 25                  Ellsworth                   15.84   44.5434   -68.4195
# 26                  Watertown                   29.03   42.3709   -71.1828
# 27                   Franklin                   41.02   39.9667   -83.0166
# 28               Natchitoches                   64.38   31.7668   -93.1335
# 29                Winterville                   48.06   35.5290   -77.4011

# %%
import hvplot.pandas
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='e2f6817e-043d-426b-9766-e8b799f4aee5'>
#   <div id="ca78dc03-50dd-4cd7-9937-a2411ca9e7b6" data-root-id="e2f6817e-043d-426b-9766-e8b799f4aee5" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"b7197ba7-90d2-4fe3-9522-f07fda12228b":{"version":"3.5.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"e2f6817e-043d-426b-9766-e8b799f4aee5"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"371c9cc0-ba08-4403-8124-feac8965cc20","attributes":{"plot_id":"e2f6817e-043d-426b-9766-e8b799f4aee5","comm_id":"2b98b546ba1d4f9eb91c3eda2fdf824b","client_comm_id":"faebdbccd08c4307aadf53b10e5cc416"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"b7197ba7-90d2-4fe3-9522-f07fda12228b","roots":{"e2f6817e-043d-426b-9766-e8b799f4aee5":"ca78dc03-50dd-4cd7-9937-a2411ca9e7b6"},"root_ids":["e2f6817e-043d-426b-9766-e8b799f4aee5"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
weatherMapPlot = cityDataDF.hvplot.points(
    "Longitude",
    "Latitude",
    geo = True,
    size = "Fahrenheit Temperature",
    scale = 1,
    color = "City Name",
    alpha = 0.5,
    tiles = "OSM",
    frame_width = 896,
    frame_height = 504,   
    hover_cols = ["City Name", "Fahrenheit Temperature"]
)
weatherMapPlot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Longitude,Latitude]   (City Name,Fahrenheit Temperature)

# %%
#'lon': -80.8431, 'lat': 35.2271 - Charlotte, NC

# %%
geoapify_key ="94348fe49a684ccbb759dd8f5915c87d"

# %%
# use the coordinates for Charlotte, NC 
latitude = 35.2271
longitude = -80.8431

# Set base URL 
base_url = "https://api.geoapify.com/v2/places"

# Set initial parameters 
category ="accommodation.hotel"
radius = 8000 # sets the raduis to search 

# set additional parameters for the search 
filters = f"circle:{longitude},{latitude},{radius}"
bias = f"proximity:{longitude},{latitude}"
limit = 10

# set up the parameters dictionary 
parameters = {
    "categories": category, 
    "limit" : limit,
    "filter": filters,
    "bias": bias,
    "apiKey": geoapify_key
}

# run a request using the parameters dictionary 
response = requests.get(base_url, params=parameters).json()

print(json.dumps(response, indent=4))
# Out:
# {
#     "type": "FeatureCollection",
#     "features": [
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Omni Charlotte Hotel",
#                 "country": "United States",
#                 "country_code": "us",
#                 "state": "North Carolina",
#                 "county": "Mecklenburg County",
#                 "city": "Charlotte",
#                 "postcode": "28202",
#                 "district": "Uptown",
#                 "street": "East Trade Street",
#                 "housenumber": "132",
#                 "lon": -80.8426236725816,
#                 "lat": 35.22621925,
#                 "state_code": "NC",
#                 "formatted": "Omni Charlotte Hotel, 132 East Trade Street, Charlotte, NC 28202, United States of America",
#                 "address_line1": "Omni Charlotte Hotel",
#                 "address_line2": "132 East Trade Street, Charlotte, NC 28202, United States of America",
#                 "categories": [
#                     "accommodation",
#                     "accommodation.hotel",
#                     "building",
#                     "building.accommodation",
#                     "internet_access"
#                 ],
#                 "details": [
#                     "details",
#                     "details.building",
#                     "details.contact",
#                     "details.facilities"
#                 ],
#                 "datasource": {
#                     "sourcename": "openstreetmap",
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database License",
#                     "url": "https://www.openstreetmap.org/copyright",
#                     "raw": {
#                         "name": "Omni Charlotte Hotel",
#                         "phone": "(704) 377-0400",
#                         "height": 28,
#                         "osm_id": 500204487,
#                         "tourism": "hotel",
#                         "website": "https://www.omnihotels.com/hotels/charlotte",
#                         "building": "yes",
#                         "operator": "Omni Hotels & Resorts",
#                         "osm_type": "w",
#                         "addr:city": "Charlotte",
#                         "addr:state": "NC",
#                         "addr:street": "East Trade Street",
#                         "addr:postcode": 28202,
#                         "brand:wikidata": "Q7090329",
#                         "brand:wikipedia": "en:Omni Hotels & Resorts",
#                         "internet_access": "yes",
#                         "addr:housenumber": 132
#                     }
#                 },
#                 "website": "https://www.omnihotels.com/hotels/charlotte",
#                 "brand_details": {
#                     "wikidata": "Q7090329",
#                     "wikipedia": "en:Omni Hotels & Resorts"
#                 },
#                 "operator": "Omni Hotels & Resorts",
#                 "contact": {
#                     "phone": "(704) 377-0400"
#                 },
#                 "facilities": {
#                     "internet_access": true
#                 },
#                 "building": {
#                     "height": 28
#                 },
#                 "distance": 33,
#                 "place_id": "51b224d78bed3554c05940869bc0f49c4140f00102f901c783d01d000000009203144f6d6e6920436861726c6f74746520486f74656c"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -80.8426236725816,
#                     35.22621924966779
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Charlotte Marriott City Center",
#                 "country": "United States",
#                 "country_code": "us",
#                 "state": "North Carolina",
#                 "county": "Mecklenburg County",
#                 "city": "Charlotte",
#                 "postcode": "28202",
#                 "district": "Uptown",
#                 "street": "West Trade Street",
#                 "housenumber": "100",
#                 "lon": -80.84346246822125,
#                 "lat": 35.227986,
#                 "state_code": "NC",
#                 "formatted": "Charlotte Marriott City Center, 100 West Trade Street, Charlotte, NC 28202, United States of America",
#                 "address_line1": "Charlotte Marriott City Center",
#                 "address_line2": "100 West Trade Street, Charlotte, NC 28202, United States of America",
#                 "categories": [
#                     "accommodation",
#                     "accommodation.hotel",
#                     "building",
#                     "building.accommodation"
#                 ],
#                 "details": [
#                     "details.wiki_and_media"
#                 ],
#                 "datasource": {
#                     "sourcename": "openstreetmap",
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database License",
#                     "url": "https://www.openstreetmap.org/copyright",
#                     "raw": {
#                         "name": "Charlotte Marriott City Center",
#                         "osm_id": 397369787,
#                         "tourism": "hotel",
#                         "building": "yes",
#                         "osm_type": "w",
#                         "wikidata": "Q111394605",
#                         "addr:city": "Charlotte",
#                         "addr:state": "NC",
#                         "addr:street": "West Trade Street",
#                         "addr:postcode": 28202,
#                         "addr:housenumber": 100
#                     }
#                 },
#                 "wiki_and_media": {
#                     "wikidata": "Q111394605"
#                 },
#                 "distance": 61,
#                 "place_id": "517a1a014afb3554c05982422ea52e9d4140f00102f901bb61af170000000092031e436861726c6f747465204d617272696f747420436974792043656e746572"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -80.84346246822125,
#                     35.22798599966792
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "The Ivey's Hotel",
#                 "country": "United States",
#                 "country_code": "us",
#                 "state": "North Carolina",
#                 "county": "Mecklenburg County",
#                 "city": "Charlotte",
#                 "postcode": "28202",
#                 "district": "Uptown",
#                 "street": "North Tryon Street",
#                 "housenumber": "127",
#                 "lon": -80.84280537782398,
#                 "lat": 35.22848785,
#                 "state_code": "NC",
#                 "formatted": "The Ivey's Hotel, 127 North Tryon Street, Charlotte, NC 28202, United States of America",
#                 "address_line1": "The Ivey's Hotel",
#                 "address_line2": "127 North Tryon Street, Charlotte, NC 28202, United States of America",
#                 "categories": [
#                     "accommodation",
#                     "accommodation.hotel",
#                     "building",
#                     "building.accommodation"
#                 ],
#                 "details": [
#                     "details.wiki_and_media"
#                 ],
#                 "datasource": {
#                     "sourcename": "openstreetmap",
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database License",
#                     "url": "https://www.openstreetmap.org/copyright",
#                     "raw": {
#                         "name": "The Ivey's Hotel",
#                         "osm_id": 985188329,
#                         "tourism": "hotel",
#                         "building": "yes",
#                         "osm_type": "w",
#                         "wikidata": "Q111394606",
#                         "addr:city": "Charlotte",
#                         "addr:state": "NC",
#                         "addr:street": "North Tryon Street",
#                         "addr:postcode": 28202,
#                         "addr:housenumber": 127
#                     }
#                 },
#                 "wiki_and_media": {
#                     "wikidata": "Q111394606"
#                 },
#                 "distance": 111,
#                 "place_id": "5168a9f785f03554c059bced00173f9d4140f00102f901e9c7b83a000000009203105468652049766579277320486f74656c"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -80.84280537782399,
#                     35.22848784966797
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "The Ritz-Carlton, Charlotte",
#                 "country": "United States",
#                 "country_code": "us",
#                 "state": "North Carolina",
#                 "county": "Mecklenburg County",
#                 "city": "Charlotte",
#                 "postcode": "28202",
#                 "district": "Uptown",
#                 "street": "East Trade Street",
#                 "housenumber": "201",
#                 "lon": -80.84147470738128,
#                 "lat": 35.2261489,
#                 "state_code": "NC",
#                 "formatted": "The Ritz-Carlton, Charlotte, 201 East Trade Street, Charlotte, NC 28202, United States of America",
#                 "address_line1": "The Ritz-Carlton, Charlotte",
#                 "address_line2": "201 East Trade Street, Charlotte, NC 28202, United States of America",
#                 "categories": [
#                     "accommodation",
#                     "accommodation.hotel",
#                     "building",
#                     "building.accommodation"
#                 ],
#                 "details": [
#                     "details",
#                     "details.building",
#                     "details.wiki_and_media"
#                 ],
#                 "datasource": {
#                     "sourcename": "openstreetmap",
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database License",
#                     "url": "https://www.openstreetmap.org/copyright",
#                     "raw": {
#                         "name": "The Ritz-Carlton, Charlotte",
#                         "brand": "The Ritz-Carlton",
#                         "height": 80,
#                         "osm_id": 380092604,
#                         "tourism": "hotel",
#                         "building": "yes",
#                         "osm_type": "w",
#                         "wikidata": "Q111394609",
#                         "addr:city": "Charlotte",
#                         "addr:state": "NC",
#                         "addr:street": "East Trade Street",
#                         "addr:postcode": 28202,
#                         "brand:wikidata": "Q782200",
#                         "addr:housenumber": 201
#                     }
#                 },
#                 "brand": "The Ritz-Carlton",
#                 "brand_details": {
#                     "wikidata": "Q782200"
#                 },
#                 "wiki_and_media": {
#                     "wikidata": "Q111394609"
#                 },
#                 "building": {
#                     "height": 80
#                 },
#                 "distance": 154,
#                 "place_id": "514827bbb8da3554c059be0c7872f29c4140f00102f901bcc0a7160000000092031b546865205269747a2d4361726c746f6e2c20436861726c6f747465"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -80.84147470738128,
#                     35.22614889966779
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Grand Bohemian Hotel Charlotte, Autograph Collection",
#                 "country": "United States",
#                 "country_code": "us",
#                 "state": "North Carolina",
#                 "county": "Mecklenburg County",
#                 "city": "Charlotte",
#                 "postcode": "28202",
#                 "district": "Uptown",
#                 "street": "West Trade Street",
#                 "housenumber": "201",
#                 "lon": -80.84474869467454,
#                 "lat": 35.2281199,
#                 "state_code": "NC",
#                 "formatted": "Grand Bohemian Hotel Charlotte, Autograph Collection, 201 West Trade Street, Charlotte, NC 28202, United States of America",
#                 "address_line1": "Grand Bohemian Hotel Charlotte, Autograph Collection",
#                 "address_line2": "201 West Trade Street, Charlotte, NC 28202, United States of America",
#                 "categories": [
#                     "accommodation",
#                     "accommodation.hotel",
#                     "building",
#                     "building.accommodation"
#                 ],
#                 "details": [],
#                 "datasource": {
#                     "sourcename": "openstreetmap",
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database License",
#                     "url": "https://www.openstreetmap.org/copyright",
#                     "raw": {
#                         "name": "Grand Bohemian Hotel Charlotte, Autograph Collection",
#                         "osm_id": 835603874,
#                         "tourism": "hotel",
#                         "building": "yes",
#                         "osm_type": "w",
#                         "addr:city": "Charlotte",
#                         "addr:state": "NC",
#                         "addr:street": "West Trade Street",
#                         "addr:postcode": 28202,
#                         "addr:housenumber": 201
#                     }
#                 },
#                 "distance": 162,
#                 "place_id": "51ce3dd45c103654c05900526a08339d4140f00102f901a24dce31000000009203344772616e6420426f68656d69616e20486f74656c20436861726c6f7474652c204175746f677261706820436f6c6c656374696f6e"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -80.84474869467451,
#                     35.228119899667945
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Aloft Charlotte Uptown at the EpiCentre",
#                 "country": "United States",
#                 "country_code": "us",
#                 "state": "North Carolina",
#                 "county": "Mecklenburg County",
#                 "city": "Charlotte",
#                 "postcode": "28202",
#                 "district": "Uptown",
#                 "street": "East Trade Street",
#                 "housenumber": "210",
#                 "lon": -80.8426764,
#                 "lat": 35.2254742,
#                 "state_code": "NC",
#                 "formatted": "Aloft Charlotte Uptown at the EpiCentre, 210 East Trade Street, Charlotte, NC 28202, United States of America",
#                 "address_line1": "Aloft Charlotte Uptown at the EpiCentre",
#                 "address_line2": "210 East Trade Street, Charlotte, NC 28202, United States of America",
#                 "categories": [
#                     "accommodation",
#                     "accommodation.hotel"
#                 ],
#                 "details": [
#                     "details"
#                 ],
#                 "datasource": {
#                     "sourcename": "openstreetmap",
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database License",
#                     "url": "https://www.openstreetmap.org/copyright",
#                     "raw": {
#                         "name": "Aloft Charlotte Uptown at the EpiCentre",
#                         "brand": "Aloft",
#                         "osm_id": 1848893643,
#                         "tourism": "hotel",
#                         "osm_type": "n",
#                         "brand:wikidata": "Q4734166"
#                     }
#                 },
#                 "brand": "Aloft",
#                 "brand_details": {
#                     "wikidata": "Q4734166"
#                 },
#                 "distance": 184,
#                 "place_id": "511cc7fe68ee3554c05917d5ac56dc9c4140f00103f901cbe0336e00000000920327416c6f667420436861726c6f747465205570746f776e206174207468652045706943656e747265"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -80.84267640000002,
#                     35.22547419966775
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Courtyard Charlotte City Center",
#                 "ref": "CLTUP",
#                 "country": "United States",
#                 "country_code": "us",
#                 "state": "North Carolina",
#                 "county": "Mecklenburg County",
#                 "city": "Charlotte",
#                 "postcode": "28202",
#                 "district": "Uptown",
#                 "street": "South Tryon Street",
#                 "housenumber": "237",
#                 "lon": -80.84472195173487,
#                 "lat": 35.2256283,
#                 "state_code": "NC",
#                 "formatted": "Courtyard Charlotte City Center, 237 South Tryon Street, Charlotte, NC 28202, United States of America",
#                 "address_line1": "Courtyard Charlotte City Center",
#                 "address_line2": "237 South Tryon Street, Charlotte, NC 28202, United States of America",
#                 "categories": [
#                     "accommodation",
#                     "accommodation.hotel"
#                 ],
#                 "details": [
#                     "details",
#                     "details.contact"
#                 ],
#                 "datasource": {
#                     "sourcename": "openstreetmap",
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database License",
#                     "url": "https://www.openstreetmap.org/copyright",
#                     "raw": {
#                         "ref": "CLTUP",
#                         "name": "Courtyard Charlotte City Center",
#                         "brand": "Courtyard",
#                         "phone": "+1 704-926-5800",
#                         "branch": "Charlotte City Center",
#                         "osm_id": 948973303,
#                         "tourism": "hotel",
#                         "website": "https://www.marriott.com/cltup",
#                         "osm_type": "w",
#                         "addr:city": "Charlotte",
#                         "addr:state": "NC",
#                         "addr:street": "South Tryon Street",
#                         "addr:postcode": 28202,
#                         "building:part": "yes",
#                         "official_name": "Courtyard by Marriott",
#                         "brand:wikidata": "Q1053170",
#                         "addr:housenumber": 237
#                     }
#                 },
#                 "website": "https://www.marriott.com/cltup",
#                 "brand": "Courtyard",
#                 "brand_details": {
#                     "wikidata": "Q1053170"
#                 },
#                 "branch": "Charlotte City Center",
#                 "name_other": {
#                     "official_name": "Courtyard by Marriott"
#                 },
#                 "contact": {
#                     "phone": "+1 704-926-5800"
#                 },
#                 "distance": 196,
#                 "place_id": "51883aa9ec0f3654c05902105c63e19c4140f00102f901f72e90380000000092031f436f7572747961726420436861726c6f74746520436974792043656e746572"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -80.84472195173487,
#                     35.22562829966775
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Holiday Inn Center City",
#                 "country": "United States",
#                 "country_code": "us",
#                 "state": "North Carolina",
#                 "county": "Mecklenburg County",
#                 "city": "Charlotte",
#                 "postcode": "28280",
#                 "district": "Uptown",
#                 "suburb": "First Ward",
#                 "street": "North College Street",
#                 "lon": -80.84016012572843,
#                 "lat": 35.2273392,
#                 "state_code": "NC",
#                 "formatted": "Holiday Inn Center City, North College Street, Charlotte, NC 28280, United States of America",
#                 "address_line1": "Holiday Inn Center City",
#                 "address_line2": "North College Street, Charlotte, NC 28280, United States of America",
#                 "categories": [
#                     "accommodation",
#                     "accommodation.hotel",
#                     "building",
#                     "building.accommodation"
#                 ],
#                 "details": [
#                     "details",
#                     "details.building",
#                     "details.wiki_and_media"
#                 ],
#                 "datasource": {
#                     "sourcename": "openstreetmap",
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database License",
#                     "url": "https://www.openstreetmap.org/copyright",
#                     "raw": {
#                         "name": "Holiday Inn Center City",
#                         "brand": "Holiday Inn",
#                         "height": 60,
#                         "osm_id": 500736212,
#                         "tourism": "hotel",
#                         "building": "yes",
#                         "osm_type": "w",
#                         "wikidata": "Q111394610",
#                         "brand:wikidata": "Q2717882"
#                     }
#                 },
#                 "brand": "Holiday Inn",
#                 "brand_details": {
#                     "wikidata": "Q2717882"
#                 },
#                 "wiki_and_media": {
#                     "wikidata": "Q111394610"
#                 },
#                 "building": {
#                     "height": 60
#                 },
#                 "distance": 237,
#                 "place_id": "5109daf92ec53554c05910d66d73199d4140f00102f901d4a0d81d00000000920317486f6c6964617920496e6e2043656e7465722043697479"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -80.84016012572842,
#                     35.22733919966788
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "AC Hotel by Marriott Charlotte City Center",
#                 "country": "United States",
#                 "country_code": "us",
#                 "state": "North Carolina",
#                 "county": "Mecklenburg County",
#                 "city": "Charlotte",
#                 "postcode": "28202",
#                 "district": "Uptown",
#                 "suburb": "Second Ward",
#                 "street": "East Trade Street",
#                 "housenumber": "210",
#                 "lon": -80.8414502,
#                 "lat": 35.2253154,
#                 "state_code": "NC",
#                 "formatted": "AC Hotel by Marriott Charlotte City Center, 210 East Trade Street, Charlotte, NC 28202, United States of America",
#                 "address_line1": "AC Hotel by Marriott Charlotte City Center",
#                 "address_line2": "210 East Trade Street, Charlotte, NC 28202, United States of America",
#                 "categories": [
#                     "accommodation",
#                     "accommodation.hotel"
#                 ],
#                 "details": [
#                     "details"
#                 ],
#                 "datasource": {
#                     "sourcename": "openstreetmap",
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database License",
#                     "url": "https://www.openstreetmap.org/copyright",
#                     "raw": {
#                         "name": "AC Hotel by Marriott Charlotte City Center",
#                         "brand": "AC Hotel",
#                         "osm_id": 9111862565,
#                         "tourism": "hotel",
#                         "osm_type": "n",
#                         "brand:wikidata": "Q5653536"
#                     }
#                 },
#                 "brand": "AC Hotel",
#                 "brand_details": {
#                     "wikidata": "Q5653536"
#                 },
#                 "distance": 249,
#                 "place_id": "519c8df051da3554c059d56d9022d79c4140f00103f90125fd1b1f0200000092032a414320486f74656c206279204d617272696f747420436861726c6f74746520436974792043656e746572"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -80.8414502,
#                     35.22531539966773
#                 ]
#             }
#         },
#         {
#             "type": "Feature",
#             "properties": {
#                 "name": "Residence Inn Charlotte City Center",
#                 "country": "United States",
#                 "country_code": "us",
#                 "state": "North Carolina",
#                 "county": "Mecklenburg County",
#                 "city": "Charlotte",
#                 "postcode": "28202",
#                 "district": "Uptown",
#                 "suburb": "Second Ward",
#                 "street": "East Trade Street",
#                 "housenumber": "220",
#                 "lon": -80.8414272,
#                 "lat": 35.2251987,
#                 "state_code": "NC",
#                 "formatted": "Residence Inn Charlotte City Center, 220 East Trade Street, Charlotte, NC 28202, United States of America",
#                 "address_line1": "Residence Inn Charlotte City Center",
#                 "address_line2": "220 East Trade Street, Charlotte, NC 28202, United States of America",
#                 "categories": [
#                     "accommodation",
#                     "accommodation.hotel"
#                 ],
#                 "details": [
#                     "details"
#                 ],
#                 "datasource": {
#                     "sourcename": "openstreetmap",
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database License",
#                     "url": "https://www.openstreetmap.org/copyright",
#                     "raw": {
#                         "name": "Residence Inn Charlotte City Center",
#                         "brand": "Residence Inn",
#                         "osm_id": 9111862564,
#                         "tourism": "hotel",
#                         "osm_type": "n",
#                         "addr:city": "Charlotte",
#                         "addr:state": "NC",
#                         "addr:street": "East Trade Street",
#                         "addr:postcode": 28202,
#                         "official_name": "Residence Inn by Marriott",
#                         "brand:wikidata": "Q7315394",
#                         "addr:housenumber": 220
#                     }
#                 },
#                 "brand": "Residence Inn",
#                 "brand_details": {
#                     "wikidata": "Q7315394"
#                 },
#                 "name_other": {
#                     "official_name": "Residence Inn by Marriott"
#                 },
#                 "distance": 260,
#                 "place_id": "51bf7d78f1d93554c05958169d4fd39c4140f00103f90124fd1b1f020000009203235265736964656e636520496e6e20436861726c6f74746520436974792043656e746572"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     -80.84142719999998,
#                     35.225198699667715
#                 ]
#             }
#         }
#     ]
# }

# %%
print("API Key:", geoapify_key)
# Out:
# API Key: 94348fe49a684ccbb759dd8f5915c87d
